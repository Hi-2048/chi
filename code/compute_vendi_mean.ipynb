# %%
import pandas as pd

# %%
sd15 = pd.read_csv("sd15.csv", index_col=0)
sd21 = pd.read_csv("sd21.csv", index_col=0)
de2 = pd.read_csv("de2.csv", index_col=0)

# %%
total = pd.concat([sd15.mean(axis=1), sd21.mean(axis=1), de2.mean(axis=1)], axis=1, keys=["SD15", "SD21", "DALLE2"])

# %%
total
# Out:
#                  SD15      SD21    DALLE2
# Belgium      6.422536  7.197419  8.775469
# Brazil       6.872546  7.258063  7.908570
# Canada       6.688444  7.262561  8.545532
# China        6.627315  6.920428  8.089387
# Colombia     6.180413  6.773686  7.514662
# Denmark      6.825780  7.322098  8.713531
# Drc          6.197485  6.548143  7.306196
# Egypt        6.654363  6.829983  7.462595
# Ethiopia     6.247268  6.254961  7.198037
# Finland      6.825993  7.391468  8.685349
# France       6.593995  7.281498  8.519884
# Germany      6.429859  7.386301  8.392239
# Greece       6.632952  6.960401  8.418520
# India        6.201368  6.386221  7.898144
# Indonesia    6.403085  6.513590  7.929400
# Iran         6.548274  6.619950  7.822019
# Italy        6.511937  7.216540  8.688482
# Japan        6.446885  7.107424  8.252994
# Mexico       6.474140  6.780680  7.788025
# Netherlands  6.283037  7.245247  8.484417
# Nigeria      6.365499  6.634146  7.074219
# ...

# %%
total.SD15
# Out:
# Belgium        6.422536
# Brazil         6.872546
# Canada         6.688444
# China          6.627315
# Colombia       6.180413
# Denmark        6.825780
# Drc            6.197485
# Egypt          6.654363
# Ethiopia       6.247268
# Finland        6.825993
# France         6.593995
# Germany        6.429859
# Greece         6.632952
# India          6.201368
# Indonesia      6.403085
# Iran           6.548274
# Italy          6.511937
# Japan          6.446885
# Mexico         6.474140
# Netherlands    6.283037
# Nigeria        6.365499
# Pakistan       6.029412
# Poland         6.632091
# Russia         6.590802
# Spain          6.601973
# Sweden         6.765573
# Turkey         6.529700
# Uk             6.465506
# Usa            6.832060
# Vietnam        6.579214
# Name: SD15, dtype: float64

# %%
total.SD21
# Out:
# Belgium        7.197419
# Brazil         7.258063
# Canada         7.262561
# China          6.920428
# Colombia       6.773686
# Denmark        7.322098
# Drc            6.548143
# Egypt          6.829983
# Ethiopia       6.254961
# Finland        7.391468
# France         7.281498
# Germany        7.386301
# Greece         6.960401
# India          6.386221
# Indonesia      6.513590
# Iran           6.619950
# Italy          7.216540
# Japan          7.107424
# Mexico         6.780680
# Netherlands    7.245247
# Nigeria        6.634146
# Pakistan       6.340258
# Poland         7.162969
# Russia         7.111731
# Spain          6.925377
# Sweden         7.272604
# Turkey         6.961677
# Uk             7.253996
# Usa            7.781445
# Vietnam        6.972616
# Name: SD21, dtype: float64

# %%
total.DALLE2
# Out:
# Belgium        8.775469
# Brazil         7.908570
# Canada         8.545532
# China          8.089387
# Colombia       7.514662
# Denmark        8.713531
# Drc            7.306196
# Egypt          7.462595
# Ethiopia       7.198037
# Finland        8.685349
# France         8.519884
# Germany        8.392239
# Greece         8.418520
# India          7.898144
# Indonesia      7.929400
# Iran           7.822019
# Italy          8.688482
# Japan          8.252994
# Mexico         7.788025
# Netherlands    8.484417
# Nigeria        7.074219
# Pakistan       7.967423
# Poland         8.479876
# Russia         7.995643
# Spain          8.505189
# Sweden         8.629526
# Turkey         8.157122
# Uk             8.642948
# Usa            9.062252
# Vietnam        7.218358
# Name: DALLE2, dtype: float64

# %%
total.to_csv("mean.csv")
